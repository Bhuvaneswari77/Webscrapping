# %% [markdown]
# **Import the required Modules:**

# %%
import requests
import time
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# **See the structure of URL:**

# %%
#https://www.flipkart.com/search?q=macbook&sid=6bo%2Cb5g&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&as-pos=1&as-type=RECENT&suggestionId=macbook%7CLaptops&requestId=725f153c-36bb-478c-8f10-e54c60187a13&as-backfill=on&page=1
#https://www.flipkart.com/search?q=macbook&sid=6bo%2Cb5g&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&as-pos=1&as-type=RECENT&suggestionId=macbook%7CLaptops&requestId=725f153c-36bb-478c-8f10-e54c60187a13&as-backfill=on&page=2

# %%
base_url = 'https://www.flipkart.com/search?q=iphone%206&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off'

# %% [markdown]
# **Create List for store the Data**

# %%
pd_name = []
price =[]
ratings = []
warranty = []
ratingsno = []
reviewsno = []
features = []
for i in range(1,3):
  time.sleep(3)
  req = requests.get(base_url+str(i))
  soup = BeautifulSoup(req.text,'html')

  #product name
  pdt_name = soup.findAll('div',attrs={'class':'_4rR01T'})
  [pd_name.append(i.text) for i in pdt_name]

  #price
  p = soup.findAll('div',attrs={'class':'_30jeq3 _1_WHN1'})
  [price.append(i.text) for i in p]

  #ratings
  r = soup.findAll('div',attrs={'class':'gUuXy-'})
  [ratings.append(i.span.div.text) for i in r]

  #warranty
  wl = soup.findAll('ul',attrs={'class':'_1xgFaf'})
  w = [i.findAll('li')[-1] for i in wl]
  [warranty.append(i.text) for i in w]

  #number of ratings and reviews
  a = soup.findAll('span',attrs={'class':'_2_R_DZ'})
  for i in a:
    a = i.text.split('&')
    ratingsno.append(a[0].split(" ")[0])
    reviewsno.append(a[1].split(" ")[0])

  #features
  prop = soup.findAll('ul',attrs={'class':'_1xgFaf'})
  for i in prop:
    a = i.findAll('li')[0:-2]
    b =[i.text for i in a]
    features.append(','.join(b))

# %%
print('pd_name= ',len(pd_name))
print('price = ',len(price))
print('ratings = ',len(ratings))
print('warranty = ',len(warranty))
print('ratingsno =',len(ratingsno))
print('reviewsno = ',len(reviewsno))
print('features = ',len(features))
# Out:
# pd_name=  48
# price =  48
# ratings =  48
# warranty =  48
# ratingsno = 48
# reviewsno =  48
# features =  48

# %%
data = pd.DataFrame({'Product':pd_name,
                     'Price':price,
                     'Ratings':ratings,
                     'Warranty':warranty,
                     'No of Ratings':ratingsno,
                     'No of Reviews':reviewsno,
                     'Features':features})
data
# Out:
#                                Product    Price Ratings  \
# 0   APPLE iPhone 6 (Space Grey, 16 GB)  ₹52,000     4.4
# 1         APPLE iPhone 6 (Gold, 32 GB)  ₹30,780     4.4
# 2   APPLE iPhone 6 (Space Grey, 32 GB)  ₹30,780     4.4
# 3       APPLE iPhone 6 (Silver, 16 GB)  ₹36,990     4.4
# 4         APPLE iPhone 6 (Gold, 64 GB)  ₹62,500     4.4
# 5        APPLE iPhone 6 (Gold, 128 GB)  ₹49,999     4.4
# 6   APPLE iPhone 6 (Space Grey, 64 GB)  ₹44,999     4.4
# 7        APPLE iPhone 6 (Grey, 128 GB)  ₹71,500     4.4
# 8      APPLE iPhone 6 (Silver, 128 GB)  ₹71,500     4.4
# 9       APPLE iPhone 6 (Silver, 64 GB)  ₹62,000     4.4
# 10     APPLE iPhone 11 (Black, 128 GB)  ₹46,999     4.6
# 11     APPLE iPhone 11 (White, 128 GB)  ₹46,999     4.6
# 12      APPLE iPhone 11 (White, 64 GB)  ₹41,999     4.6
# 13    APPLE iPhone 11 (Purple, 128 GB)  ₹46,999     4.6
# 14      APPLE iPhone 11 (Black, 64 GB)  ₹41,999     4.6
# 15     APPLE iPhone 11 (Purple, 64 GB)  ₹41,999     4.6
# 16        APPLE iPhone 11 (Red, 64 GB)  ₹41,999     4.6
# 17      APPLE iPhone 12 (White, 64 GB)  ₹53,999     4.6
# 18       APPLE iPhone 12 (Blue, 64 GB)  ₹53,999     4.6
# 19     APPLE iPhone 12 (White, 128 GB)  ₹58,999     4.6
# 20  APPLE iPhone 13 (Midnight, 128 GB)  ₹69,999     4.6
# 21     APPLE iPhone 12 (Black, 128 GB)  ₹58,999     4.6
# 22       APPLE iPhone 11 (Red, 128 GB)  ₹46,999     4.6
# 23      APPLE iPhone 13 (Blue, 128 GB)  ₹69,999     4.6
# 24  APPLE iPhone 6 (Space Grey, 16 GB)  ₹52,000     4.4
# 25        APPLE iPhone 6 (Gold, 32 GB)  ₹30,780     4.4
# 26  APPLE iPhone 6 (Space Grey, 32 GB)  ₹30,780     4.4
# 27      APPLE iPhone 6 (Silver, 16 GB)  ₹36,990     4.4
# 28        APPLE iPhone 6 (Gold, 64 GB)  ₹62,500     4.4
# 29       APPLE iPhone 6 (Gold, 128 GB)  ₹49,999     4.4
# 30  APPLE iPhone 6 (Space Grey, 64 GB)  ₹44,999     4.4
# 31       APPLE iPhone 6 (Grey, 128 GB)  ₹71,500     4.4
# 32     APPLE iPhone 6 (Silver, 128 GB)  ₹71,500     4.4
# 33      APPLE iPhone 6 (Silver, 64 GB)  ₹62,000     4.4
# 34     APPLE iPhone 11 (Black, 128 GB)  ₹46,999     4.6
# 35     APPLE iPhone 11 (White, 128 GB)  ₹46,999     4.6
# 36      APPLE iPhone 11 (White, 64 GB)  ₹41,999     4.6
# 37    APPLE iPhone 11 (Purple, 128 GB)  ₹46,999     4.6
# 38      APPLE iPhone 11 (Black, 64 GB)  ₹41,999     4.6
# 39     APPLE iPhone 11 (Purple, 64 GB)  ₹41,999     4.6
# 40        APPLE iPhone 11 (Red, 64 GB)  ₹41,999     4.6
